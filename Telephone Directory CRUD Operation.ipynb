# %%
                                '''Telephone Directory CRUD Operation'''
import pymongo
import datetime
import json
from pymongo import MongoClient, InsertOne

# %%
client = pymongo.MongoClient("mongodb://127.0.0.1:27017")
db = client.test

# %%
client.list_database_names()
# Out:
# ['StudentDatabase',
#  'Telephone_directory11',
#  'admin',
#  'config',
#  'guvi',
#  'guvi2',
#  'local',
#  'mydb',
#  'student',
#  'student_database1',
#  'test',
#  'tymongo']

# %%
mycol = db ["Telephone Directory"]

# %%
"""Insert Collections"""

mydict = [{'Phone_number': '+91 1234567899','Place':'Chennai','State': 'TamilNadu','Name':'Kumar'},
         {'Phone_number': '+91 1234567895','Place':'Madurai','State': 'TamilNadu','Name':'Stephen'},
         {'Phone_number': '+91 1234567850','Place':'Mumbai','State':'Maharashtra','Name':'Aditi'},
         {'Phone_number': '+91 1234567550','Place':'Bengaluru','State':'Karnataka','Name':'Bhavna'},
         {'Phone_number': '+91 1234567220','Place':'Shahdara','State':'Delhi','Name':'DarshanKumar'},
         {'Phone_number': '+91 1234567150','Place':'Hoshiarpur','State':'Punjab','Name':'BalaKumar'},
         {'Phone_number': '+91 1234567815','Place':'Alluri Sitarama Raju','State':'Andhra Pradesh','Name':'AishwaryaKumari'},
         {'Phone_number': '+91 1234567813','Place':'Bundi','State':'Rajasthan','Name':'Ashok'},
         {'Phone_number': '+91 1234567884','Place':'Hyderabad','State':'Telangana','Name':'Bimala'},
         {'Phone_number': '+91 1234567125','Place':'Khowai','State':'Tripura','Name':'Darshan'}]

x = mycol.insert_many(mydict)
type(x)
# Out:
# pymongo.results.InsertManyResult

# %%
y = mycol.find()
list(y)
# Out:
# [{'_id': ObjectId('63583d86a9bd744ea6a7c37f'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c380'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c381'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c382'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c383'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c384'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c385'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c386'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c387'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c388'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c389'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38a'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38b'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38c'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38d'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38e'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c38f'),
#   'Phone_number': '+91 1234567899',
#   'Place': 'Chennai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c390'),
#   'Phone_number': '+91 1234567895',
#   'Place': 'Madurai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c391'),
#   'Phone_number': '+91 1234567850',
#   'Place': 'Mumbai',
#   'State': 'Maharashtra',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c392'),
#   'Phone_number': '+91 1234567550',
#   'Place': 'Bengaluru',
#   'State': 'Karnataka',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c393'),
#   'Phone_number': '+91 1234567220',
#   'Place': 'Shahdara',
#   'State': 'Delhi',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c394'),
#   'Phone_number': '+91 1234567150',
#   'Place': 'Hoshiarpur',
#   'State': 'Punjab',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c395'),
#   'Phone_number': '+91 1234567815',
#   'Place': 'Alluri Sitarama Raju',
#   'State': 'Andhra Pradesh',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c396'),
#   'Phone_number': '+91 1234567813',
#   'Place': 'Bundi',
#   'State': 'Rajasthan',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c397'),
#   'Phone_number': '+91 1234567884',
#   'Place': 'Hyderabad',
#   'State': 'Telangana',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c398'),
#   'Phone_number': '+91 1234567125',
#   'Place': 'Khowai',
#   'State': 'Tripura',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c399'),
#   'Phone_number': '+91 1234567899',
#   'Place': 'Chennai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39a'),
#   'Phone_number': '+91 1234567895',
#   'Place': 'Madurai',
#   'State': 'TamilNadu',
#   'Name': 'Stephen'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39b'),
#   'Phone_number': '+91 1234567850',
#   'Place': 'Mumbai',
#   'State': 'Maharashtra',
#   'Name': 'Aditi'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39c'),
#   'Phone_number': '+91 1234567550',
#   'Place': 'Bengaluru',
#   'State': 'Karnataka',
#   'Name': 'Bhavna'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39d'),
#   'Phone_number': '+91 1234567220',
#   'Place': 'Shahdara',
#   'State': 'Delhi',
#   'Name': 'DarshanKumar'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39e'),
#   'Phone_number': '+91 1234567150',
#   'Place': 'Hoshiarpur',
#   'State': 'Punjab',
#   'Name': 'BalaKumar'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39f'),
#   'Phone_number': '+91 1234567815',
#   'Place': 'Alluri Sitarama Raju',
#   'State': 'Andhra Pradesh',
#   'Name': 'AishwaryaKumari'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c3a0'),
#   'Phone_number': '+91 1234567813',
#   'Place': 'Bundi',
#   'State': 'Rajasthan',
#   'Name': 'Ashok'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c3a1'),
#   'Phone_number': '+91 1234567884',
#   'Place': 'Hyderabad',
#   'State': 'Telangana',
#   'Name': 'Bimala'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c3a2'),
#   'Phone_number': '+91 1234567125',
#   'Place': 'Khowai',
#   'State': 'Tripura',
#   'Name': 'Darshan'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a3'),
#   'Phone_number': '+91 1234567899',
#   'Place': 'Chennai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a4'),
#   'Phone_number': '+91 1234567895',
#   'Place': 'Madurai',
#   'State': 'TamilNadu',
#   'Name': 'Stephen'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a5'),
#   'Phone_number': '+91 1234567850',
#   'Place': 'Mumbai',
#   'State': 'Maharashtra',
#   'Name': 'Aditi'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a6'),
#   'Phone_number': '+91 1234567550',
#   'Place': 'Bengaluru',
#   'State': 'Karnataka',
#   'Name': 'Bhavna'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a7'),
#   'Phone_number': '+91 1234567220',
#   'Place': 'Shahdara',
#   'State': 'Delhi',
#   'Name': 'DarshanKumar'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a8'),
#   'Phone_number': '+91 1234567150',
#   'Place': 'Hoshiarpur',
#   'State': 'Punjab',
#   'Name': 'BalaKumar'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a9'),
#   'Phone_number': '+91 1234567815',
#   'Place': 'Alluri Sitarama Raju',
#   'State': 'Andhra Pradesh',
#   'Name': 'AishwaryaKumari'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3aa'),
#   'Phone_number': '+91 1234567813',
#   'Place': 'Bundi',
#   'State': 'Rajasthan',
#   'Name': 'Ashok'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3ab'),
#   'Phone_number': '+91 1234567884',
#   'Place': 'Hyderabad',
#   'State': 'Telangana',
#   'Name': 'Bimala'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3ac'),
#   'Phone_number': '+91 1234567125',
#   'Place': 'Khowai',
#   'State': 'Tripura',
#   'Name': 'Darshan'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b91'),
#   'Phone_number': '+91 1234567899',
#   'Place': 'Chennai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b92'),
#   'Phone_number': '+91 1234567895',
#   'Place': 'Madurai',
#   'State': 'TamilNadu',
#   'Name': 'Stephen'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b93'),
#   'Phone_number': '+91 1234567850',
#   'Place': 'Mumbai',
#   'State': 'Maharashtra',
#   'Name': 'Aditi'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b94'),
#   'Phone_number': '+91 1234567550',
#   'Place': 'Bengaluru',
#   'State': 'Karnataka',
#   'Name': 'Bhavna'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b95'),
#   'Phone_number': '+91 1234567220',
#   'Place': 'Shahdara',
#   'State': 'Delhi',
#   'Name': 'DarshanKumar'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b96'),
#   'Phone_number': '+91 1234567150',
#   'Place': 'Hoshiarpur',
#   'State': 'Punjab',
#   'Name': 'BalaKumar'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b97'),
#   'Phone_number': '+91 1234567815',
#   'Place': 'Alluri Sitarama Raju',
#   'State': 'Andhra Pradesh',
#   'Name': 'AishwaryaKumari'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b98'),
#   'Phone_number': '+91 1234567813',
#   'Place': 'Bundi',
#   'State': 'Rajasthan',
#   'Name': 'Ashok'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b99'),
#   'Phone_number': '+91 1234567884',
#   'Place': 'Hyderabad',
#   'State': 'Telangana',
#   'Name': 'Bimala'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b9a'),
#   'Phone_number': '+91 1234567125',
#   'Place': 'Khowai',
#   'State': 'Tripura',
#   'Name': 'Darshan'}]

# %%
z = mycol.find({'Name':'Kumar'})
list(z)
# Out:
# [{'_id': ObjectId('63583d86a9bd744ea6a7c37f'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c380'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c381'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c382'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c383'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c384'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c385'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c386'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c387'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c388'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c389'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38a'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38b'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38c'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38d'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38e'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c38f'),
#   'Phone_number': '+91 1234567899',
#   'Place': 'Chennai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c390'),
#   'Phone_number': '+91 1234567895',
#   'Place': 'Madurai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c391'),
#   'Phone_number': '+91 1234567850',
#   'Place': 'Mumbai',
#   'State': 'Maharashtra',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c392'),
#   'Phone_number': '+91 1234567550',
#   'Place': 'Bengaluru',
#   'State': 'Karnataka',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c393'),
#   'Phone_number': '+91 1234567220',
#   'Place': 'Shahdara',
#   'State': 'Delhi',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c394'),
#   'Phone_number': '+91 1234567150',
#   'Place': 'Hoshiarpur',
#   'State': 'Punjab',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c395'),
#   'Phone_number': '+91 1234567815',
#   'Place': 'Alluri Sitarama Raju',
#   'State': 'Andhra Pradesh',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c396'),
#   'Phone_number': '+91 1234567813',
#   'Place': 'Bundi',
#   'State': 'Rajasthan',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c397'),
#   'Phone_number': '+91 1234567884',
#   'Place': 'Hyderabad',
#   'State': 'Telangana',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c398'),
#   'Phone_number': '+91 1234567125',
#   'Place': 'Khowai',
#   'State': 'Tripura',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c399'),
#   'Phone_number': '+91 1234567899',
#   'Place': 'Chennai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a3'),
#   'Phone_number': '+91 1234567899',
#   'Place': 'Chennai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b91'),
#   'Phone_number': '+91 1234567899',
#   'Place': 'Chennai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'}]

# %%
myquery = {"Nmae": "Kumar"}
newvalues = {"$set":{"Name": "BalaKumar"}}
update = mycol.update_one(myquery,newvalues)
list(mycol.find())
# Out:
# [{'_id': ObjectId('63583d86a9bd744ea6a7c37f'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c380'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c381'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c382'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c383'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c384'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c385'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c386'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c387'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c388'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c389'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38a'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38b'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38c'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38d'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38e'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c38f'),
#   'Phone_number': '+91 1234567899',
#   'Place': 'Chennai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c390'),
#   'Phone_number': '+91 1234567895',
#   'Place': 'Madurai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c391'),
#   'Phone_number': '+91 1234567850',
#   'Place': 'Mumbai',
#   'State': 'Maharashtra',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c392'),
#   'Phone_number': '+91 1234567550',
#   'Place': 'Bengaluru',
#   'State': 'Karnataka',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c393'),
#   'Phone_number': '+91 1234567220',
#   'Place': 'Shahdara',
#   'State': 'Delhi',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c394'),
#   'Phone_number': '+91 1234567150',
#   'Place': 'Hoshiarpur',
#   'State': 'Punjab',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c395'),
#   'Phone_number': '+91 1234567815',
#   'Place': 'Alluri Sitarama Raju',
#   'State': 'Andhra Pradesh',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c396'),
#   'Phone_number': '+91 1234567813',
#   'Place': 'Bundi',
#   'State': 'Rajasthan',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c397'),
#   'Phone_number': '+91 1234567884',
#   'Place': 'Hyderabad',
#   'State': 'Telangana',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c398'),
#   'Phone_number': '+91 1234567125',
#   'Place': 'Khowai',
#   'State': 'Tripura',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c399'),
#   'Phone_number': '+91 1234567899',
#   'Place': 'Chennai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39a'),
#   'Phone_number': '+91 1234567895',
#   'Place': 'Madurai',
#   'State': 'TamilNadu',
#   'Name': 'Stephen'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39b'),
#   'Phone_number': '+91 1234567850',
#   'Place': 'Mumbai',
#   'State': 'Maharashtra',
#   'Name': 'Aditi'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39c'),
#   'Phone_number': '+91 1234567550',
#   'Place': 'Bengaluru',
#   'State': 'Karnataka',
#   'Name': 'Bhavna'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39d'),
#   'Phone_number': '+91 1234567220',
#   'Place': 'Shahdara',
#   'State': 'Delhi',
#   'Name': 'DarshanKumar'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39e'),
#   'Phone_number': '+91 1234567150',
#   'Place': 'Hoshiarpur',
#   'State': 'Punjab',
#   'Name': 'BalaKumar'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39f'),
#   'Phone_number': '+91 1234567815',
#   'Place': 'Alluri Sitarama Raju',
#   'State': 'Andhra Pradesh',
#   'Name': 'AishwaryaKumari'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c3a0'),
#   'Phone_number': '+91 1234567813',
#   'Place': 'Bundi',
#   'State': 'Rajasthan',
#   'Name': 'Ashok'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c3a1'),
#   'Phone_number': '+91 1234567884',
#   'Place': 'Hyderabad',
#   'State': 'Telangana',
#   'Name': 'Bimala'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c3a2'),
#   'Phone_number': '+91 1234567125',
#   'Place': 'Khowai',
#   'State': 'Tripura',
#   'Name': 'Darshan'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a3'),
#   'Phone_number': '+91 1234567899',
#   'Place': 'Chennai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a4'),
#   'Phone_number': '+91 1234567895',
#   'Place': 'Madurai',
#   'State': 'TamilNadu',
#   'Name': 'Stephen'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a5'),
#   'Phone_number': '+91 1234567850',
#   'Place': 'Mumbai',
#   'State': 'Maharashtra',
#   'Name': 'Aditi'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a6'),
#   'Phone_number': '+91 1234567550',
#   'Place': 'Bengaluru',
#   'State': 'Karnataka',
#   'Name': 'Bhavna'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a7'),
#   'Phone_number': '+91 1234567220',
#   'Place': 'Shahdara',
#   'State': 'Delhi',
#   'Name': 'DarshanKumar'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a8'),
#   'Phone_number': '+91 1234567150',
#   'Place': 'Hoshiarpur',
#   'State': 'Punjab',
#   'Name': 'BalaKumar'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a9'),
#   'Phone_number': '+91 1234567815',
#   'Place': 'Alluri Sitarama Raju',
#   'State': 'Andhra Pradesh',
#   'Name': 'AishwaryaKumari'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3aa'),
#   'Phone_number': '+91 1234567813',
#   'Place': 'Bundi',
#   'State': 'Rajasthan',
#   'Name': 'Ashok'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3ab'),
#   'Phone_number': '+91 1234567884',
#   'Place': 'Hyderabad',
#   'State': 'Telangana',
#   'Name': 'Bimala'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3ac'),
#   'Phone_number': '+91 1234567125',
#   'Place': 'Khowai',
#   'State': 'Tripura',
#   'Name': 'Darshan'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b91'),
#   'Phone_number': '+91 1234567899',
#   'Place': 'Chennai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b92'),
#   'Phone_number': '+91 1234567895',
#   'Place': 'Madurai',
#   'State': 'TamilNadu',
#   'Name': 'Stephen'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b93'),
#   'Phone_number': '+91 1234567850',
#   'Place': 'Mumbai',
#   'State': 'Maharashtra',
#   'Name': 'Aditi'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b94'),
#   'Phone_number': '+91 1234567550',
#   'Place': 'Bengaluru',
#   'State': 'Karnataka',
#   'Name': 'Bhavna'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b95'),
#   'Phone_number': '+91 1234567220',
#   'Place': 'Shahdara',
#   'State': 'Delhi',
#   'Name': 'DarshanKumar'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b96'),
#   'Phone_number': '+91 1234567150',
#   'Place': 'Hoshiarpur',
#   'State': 'Punjab',
#   'Name': 'BalaKumar'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b97'),
#   'Phone_number': '+91 1234567815',
#   'Place': 'Alluri Sitarama Raju',
#   'State': 'Andhra Pradesh',
#   'Name': 'AishwaryaKumari'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b98'),
#   'Phone_number': '+91 1234567813',
#   'Place': 'Bundi',
#   'State': 'Rajasthan',
#   'Name': 'Ashok'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b99'),
#   'Phone_number': '+91 1234567884',
#   'Place': 'Hyderabad',
#   'State': 'Telangana',
#   'Name': 'Bimala'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b9a'),
#   'Phone_number': '+91 1234567125',
#   'Place': 'Khowai',
#   'State': 'Tripura',
#   'Name': 'Darshan'}]

# %%
myquery = {"Nmae":"Kumar"}
mycol.delete_one(myquery)

# %%
list(mycol.find())
# Out:
# [{'_id': ObjectId('63583d86a9bd744ea6a7c37f'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c380'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c381'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c382'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c383'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c384'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c385'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c386'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c387'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c388'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c389'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38a'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38b'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38c'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38d'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63583d86a9bd744ea6a7c38e'),
#   'Phone_number': '+91 1234567890',
#   'Place': 'Chennai',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c38f'),
#   'Phone_number': '+91 1234567899',
#   'Place': 'Chennai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c390'),
#   'Phone_number': '+91 1234567895',
#   'Place': 'Madurai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c391'),
#   'Phone_number': '+91 1234567850',
#   'Place': 'Mumbai',
#   'State': 'Maharashtra',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c392'),
#   'Phone_number': '+91 1234567550',
#   'Place': 'Bengaluru',
#   'State': 'Karnataka',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c393'),
#   'Phone_number': '+91 1234567220',
#   'Place': 'Shahdara',
#   'State': 'Delhi',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c394'),
#   'Phone_number': '+91 1234567150',
#   'Place': 'Hoshiarpur',
#   'State': 'Punjab',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c395'),
#   'Phone_number': '+91 1234567815',
#   'Place': 'Alluri Sitarama Raju',
#   'State': 'Andhra Pradesh',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c396'),
#   'Phone_number': '+91 1234567813',
#   'Place': 'Bundi',
#   'State': 'Rajasthan',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c397'),
#   'Phone_number': '+91 1234567884',
#   'Place': 'Hyderabad',
#   'State': 'Telangana',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('63584e1fa9bd744ea6a7c398'),
#   'Phone_number': '+91 1234567125',
#   'Place': 'Khowai',
#   'State': 'Tripura',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c399'),
#   'Phone_number': '+91 1234567899',
#   'Place': 'Chennai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39a'),
#   'Phone_number': '+91 1234567895',
#   'Place': 'Madurai',
#   'State': 'TamilNadu',
#   'Name': 'Stephen'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39b'),
#   'Phone_number': '+91 1234567850',
#   'Place': 'Mumbai',
#   'State': 'Maharashtra',
#   'Name': 'Aditi'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39c'),
#   'Phone_number': '+91 1234567550',
#   'Place': 'Bengaluru',
#   'State': 'Karnataka',
#   'Name': 'Bhavna'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39d'),
#   'Phone_number': '+91 1234567220',
#   'Place': 'Shahdara',
#   'State': 'Delhi',
#   'Name': 'DarshanKumar'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39e'),
#   'Phone_number': '+91 1234567150',
#   'Place': 'Hoshiarpur',
#   'State': 'Punjab',
#   'Name': 'BalaKumar'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c39f'),
#   'Phone_number': '+91 1234567815',
#   'Place': 'Alluri Sitarama Raju',
#   'State': 'Andhra Pradesh',
#   'Name': 'AishwaryaKumari'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c3a0'),
#   'Phone_number': '+91 1234567813',
#   'Place': 'Bundi',
#   'State': 'Rajasthan',
#   'Name': 'Ashok'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c3a1'),
#   'Phone_number': '+91 1234567884',
#   'Place': 'Hyderabad',
#   'State': 'Telangana',
#   'Name': 'Bimala'},
#  {'_id': ObjectId('6358e5baa9bd744ea6a7c3a2'),
#   'Phone_number': '+91 1234567125',
#   'Place': 'Khowai',
#   'State': 'Tripura',
#   'Name': 'Darshan'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a3'),
#   'Phone_number': '+91 1234567899',
#   'Place': 'Chennai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a4'),
#   'Phone_number': '+91 1234567895',
#   'Place': 'Madurai',
#   'State': 'TamilNadu',
#   'Name': 'Stephen'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a5'),
#   'Phone_number': '+91 1234567850',
#   'Place': 'Mumbai',
#   'State': 'Maharashtra',
#   'Name': 'Aditi'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a6'),
#   'Phone_number': '+91 1234567550',
#   'Place': 'Bengaluru',
#   'State': 'Karnataka',
#   'Name': 'Bhavna'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a7'),
#   'Phone_number': '+91 1234567220',
#   'Place': 'Shahdara',
#   'State': 'Delhi',
#   'Name': 'DarshanKumar'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a8'),
#   'Phone_number': '+91 1234567150',
#   'Place': 'Hoshiarpur',
#   'State': 'Punjab',
#   'Name': 'BalaKumar'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3a9'),
#   'Phone_number': '+91 1234567815',
#   'Place': 'Alluri Sitarama Raju',
#   'State': 'Andhra Pradesh',
#   'Name': 'AishwaryaKumari'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3aa'),
#   'Phone_number': '+91 1234567813',
#   'Place': 'Bundi',
#   'State': 'Rajasthan',
#   'Name': 'Ashok'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3ab'),
#   'Phone_number': '+91 1234567884',
#   'Place': 'Hyderabad',
#   'State': 'Telangana',
#   'Name': 'Bimala'},
#  {'_id': ObjectId('6358e5dea9bd744ea6a7c3ac'),
#   'Phone_number': '+91 1234567125',
#   'Place': 'Khowai',
#   'State': 'Tripura',
#   'Name': 'Darshan'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b91'),
#   'Phone_number': '+91 1234567899',
#   'Place': 'Chennai',
#   'State': 'TamilNadu',
#   'Name': 'Kumar'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b92'),
#   'Phone_number': '+91 1234567895',
#   'Place': 'Madurai',
#   'State': 'TamilNadu',
#   'Name': 'Stephen'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b93'),
#   'Phone_number': '+91 1234567850',
#   'Place': 'Mumbai',
#   'State': 'Maharashtra',
#   'Name': 'Aditi'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b94'),
#   'Phone_number': '+91 1234567550',
#   'Place': 'Bengaluru',
#   'State': 'Karnataka',
#   'Name': 'Bhavna'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b95'),
#   'Phone_number': '+91 1234567220',
#   'Place': 'Shahdara',
#   'State': 'Delhi',
#   'Name': 'DarshanKumar'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b96'),
#   'Phone_number': '+91 1234567150',
#   'Place': 'Hoshiarpur',
#   'State': 'Punjab',
#   'Name': 'BalaKumar'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b97'),
#   'Phone_number': '+91 1234567815',
#   'Place': 'Alluri Sitarama Raju',
#   'State': 'Andhra Pradesh',
#   'Name': 'AishwaryaKumari'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b98'),
#   'Phone_number': '+91 1234567813',
#   'Place': 'Bundi',
#   'State': 'Rajasthan',
#   'Name': 'Ashok'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b99'),
#   'Phone_number': '+91 1234567884',
#   'Place': 'Hyderabad',
#   'State': 'Telangana',
#   'Name': 'Bimala'},
#  {'_id': ObjectId('6358fa6d69cdbfa2a9967b9a'),
#   'Phone_number': '+91 1234567125',
#   'Place': 'Khowai',
#   'State': 'Tripura',
#   'Name': 'Darshan'}]
